# %%
# %matplotlib inline

import h5py
import numpy as np
from matplotlib import pyplot as plt
from data import transforms as T
import torch

# %%
# %pwd
# Out:
# '/Users/yg/code/github/fastMRI'

# %%
file = "experiments/1epoch/reconstructions/file1000022_v2.h5"
hf = h5py.File(file)

# %%
print('Keys:', list(hf.keys()))
print('Attrs:', dict(hf.attrs))
# Out:
# Keys: ['reconstruction']
# Attrs: {}

# %%
volume_kspace = hf['reconstruction'][()]
print(volume_kspace.dtype)
print(volume_kspace.shape)
slice_kspace = volume_kspace[0]
print(slice_kspace.dtype, slice_kspace.shape)
# Out:
# float32
# (37, 320, 320)
# float32 (320, 320)

# %%
slice_image = T.to_tensor(slice_kspace)      # Convert from numpy array to pytorch tensor
imgplot = plt.imshow(slice_image, cmap="gray")
plt.show()

# %%
file = "data/singlecoil_test/file1000022_v2.h5"
hf = h5py.File(file)

# %%
volume_kspace = hf['kspace'][()]
print(volume_kspace.dtype)
print(volume_kspace.shape)
slice_kspace = volume_kspace[20]
print(slice_kspace.dtype, slice_kspace.shape)
# Out:
# complex64
# (37, 640, 368)
# complex64 (640, 368)

# %%
slice_kspace2 = T.to_tensor(slice_kspace)      # Convert from numpy array to pytorch tensor
print(slice_kspace2.dtype)
slice_image = T.ifft2(slice_kspace2)           # Apply Inverse Fourier Transform to get the complex image
slice_image_abs = T.complex_abs(slice_image)
slice_image_abs.shape
# Out:
# torch.float32
# torch.Size([640, 368])

# %%
plt.imshow(slice_image_abs, cmap='gray')
